# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import numpy as np

# %%
car_data = pd.read_csv("D:/DSPGC/4. Machine Learning/car_price.csv")

# %%
car_data
# Out:
#             Id   Manufacturer         Model  Prod_Year   Category  \
# 0     45624039           FORD       Mustang       2016  Cabriolet
# 1     45766794     MITSUBISHI        Pajero       1997       Jeep
# 2     45709646         TOYOTA         RAV 4       2001       Jeep
# 3     45816588         SUZUKI  Grand Vitara       2008       Jeep
# 4     45759758     MITSUBISHI   Pajero Mini       2006       Jeep
# ...        ...            ...           ...        ...        ...
# 4814  45602856          LEXUS        IS 250       2015      Sedan
# 4815  45089354            BMW           528       2014      Sedan
# 4816  45264871           FORD        Escape       2011       Jeep
# 4817  45510310         TOYOTA  Land Cruiser       2008       Jeep
# 4818  45801572  MERCEDES-BENZ         E 350       2012      Sedan
#
#      Leather_Interioe Fuel_Type Engine Volume  Kilometers_Driven  \
# 0                 Yes    Petrol     2.3 Turbo            75000.0
# ...

# %%
car_data.head()
# Out:
#          Id Manufacturer         Model  Prod_Year   Category Leather_Interioe  \
# 0  45624039         FORD       Mustang       2016  Cabriolet              Yes
# 1  45766794   MITSUBISHI        Pajero       1997       Jeep               No
# 2  45709646       TOYOTA         RAV 4       2001       Jeep               No
# 3  45816588       SUZUKI  Grand Vitara       2008       Jeep               No
# 4  45759758   MITSUBISHI   Pajero Mini       2006       Jeep               No
#
#   Fuel_Type Engine Volume  Kilometers_Driven Gear_Box_Type Drive_Wheel  \
# 0    Petrol     2.3 Turbo            75000.0     Tiptronic        Rear
# 1    Petrol           2.4           142000.0     Automatic         4x4
# 2    Petrol             2            91000.0     Automatic         4x4
# 3    Petrol           1.6            98000.0     Automatic         4x4
# 4    Petrol           0.7           314000.0        Manual         4x4
#
#   Selling_Date             Wheel   Color  Airbags   Price
# ...

# %%
car_data.shape
# Out:
# (4819, 16)

# %%
sns.countplot(x='Leather_Interioe', data=car_data)
# Out:
# <Axes: xlabel='Leather_Interioe', ylabel='count'>

# %%
sns.countplot(x='Fuel_Type', data=car_data)
# Out:
# <Axes: xlabel='Fuel_Type', ylabel='count'>

# %%
sns.countplot(x='Gear_Box_Type', data=car_data)
# Out:
# <Axes: xlabel='Gear_Box_Type', ylabel='count'>

# %%
sns.countplot(x='Drive_Wheel', data=car_data)
# Out:
# <Axes: xlabel='Drive_Wheel', ylabel='count'>

# %%
sns.countplot(x='Wheel', data=car_data)
# Out:
# <Axes: xlabel='Wheel', ylabel='count'>

# %%
sns.countplot(x='Category', data=car_data)
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
sns.countplot(x='Color', data=car_data)
# Out:
# <Axes: xlabel='Color', ylabel='count'>

# %%
sns.scatterplot(x='Kilometers_Driven',y='Price', data= car_data)
# Out:
# <Axes: xlabel='Kilometers_Driven', ylabel='Price'>

# %%
sns.scatterplot(x='Airbags',y='Price', data= car_data)
# Out:
# <Axes: xlabel='Airbags', ylabel='Price'>

# %%
car_data.describe()
# Out:
#                  Id   Prod_Year  Kilometers_Driven      Airbags         Price
# count  4.819000e+03  4819.00000       4.733000e+03  4650.000000  4.819000e+03
# mean   4.562941e+07  2011.30110       1.708417e+06     6.772688  2.181001e+05
# std    6.639721e+05     5.43882       5.107095e+07     3.912210  1.911478e+05
# min    2.813594e+07  1943.00000       1.600000e+03     0.000000  2.038000e+04
# 25%    4.572981e+07  2010.00000       7.267800e+04     4.000000  1.003600e+05
# 50%    4.577619e+07  2012.00000       1.245090e+05     6.000000  1.724900e+05
# 75%    4.580211e+07  2015.00000       1.840000e+05    12.000000  2.728400e+05
# max    4.581665e+07  2020.00000       2.147484e+09    16.000000  2.885210e+06
